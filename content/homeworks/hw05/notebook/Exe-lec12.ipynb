# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
# %matplotlib inline
from tensorflow.keras.models import Sequential, Model
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import layers, Model, Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

from PIL import Image
import scipy.ndimage as ndi
import pandas as pd
import numpy as np

# %%
# We have 3 images 
pavlos_img_ptr = np.array(Image.open("pavlos.jpeg"))
notpavlos_img_ptr = np.array(Image.open("not-pavlos.jpeg"))
notpavlos2_img_ptr = np.array(Image.open("not-pavlos2.jpg"))

def img_resize(imgs_in, factor):
    imgs_out_train = ndi.zoom(imgs_in, (1, factor, factor, 1), order=2)
    return imgs_out_train
    

#Reduce image size to 100x100
#train
SIZE=100
pavlos_img_ptr = pavlos_img_ptr[:,:,2].reshape(1,150,150,1)
pavlos_img_ptr = img_resize(pavlos_img_ptr, SIZE/pavlos_img_ptr.shape[1])
pavlos_img_nice = pavlos_img_ptr

 
notpavlos_img_ptr = notpavlos_img_ptr[:,:,2].reshape(1,132,132,1)
notpavlos_img_ptr = img_resize(notpavlos_img_ptr,SIZE/notpavlos_img_ptr.shape[1])
notpavlos_img_nice = notpavlos_img_ptr

 
notpavlos2_img_ptr = notpavlos2_img_ptr[:,:,2].reshape(1,100,100,1)
notpavlos2_img_ptr = img_resize(notpavlos2_img_ptr, SIZE/notpavlos2_img_ptr.shape[1])
notpavlos2_img_nice  = notpavlos2_img_ptr

# %%
pavlos_flatten = pavlos_img_nice.reshape(100*100,1)
print(pavlos_flatten.shape)

notpavlos_flatten = notpavlos_img_nice.reshape(100*100,1)
print(notpavlos_flatten.shape)

notpavlos2_flatten = notpavlos2_img_nice.reshape(100*100,1)
print(notpavlos2_flatten.shape)
# Out:
# (10000, 1)
# (10000, 1)
# (10000, 1)

# %% [markdown]
# ### Create model and train

# %%
### edTest(test_check) ###
# create an AE and fit it with our data using 8 neurons in the dense layer using keras' functional API

input_dim = pavlos_flatten.shape[0]
encoding_dim = 8 

input_layer = Input(shape=(input_dim,))
encoded = Dense(encoding_dim, activation='linear', use_bias=True)(input_layer)
encoder = Model(input_layer, encoded, name='simpleenc' )


# Decoder
latent_input = Input(shape=(encoding_dim,))
decoded = Dense(input_dim, activation='linear', use_bias=True)(latent_input)
decoder = Model(latent_input, decoded, name='ldec')

autoencoder = Sequential(name='AE')
autoencoder.add(encoder)
autoencoder.add(decoder)
autoencoder.compile(loss='mse', optimizer=Adam(lr=0.001))

autoencoder.summary()


history = autoencoder.fit(pavlos_flatten.reshape(-1,input_dim), pavlos_flatten.reshape(-1,input_dim),
                epochs=100,
                batch_size=1000,
                shuffle=True,
                verbose = 1)
# Out:
# Model: "AE"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simpleenc (Model)            (None, 8)                 80008
# _________________________________________________________________
# ldec (Model)                 (None, 10000)             90000
# =================================================================
# Total params: 170,008
# Trainable params: 170,008
# Non-trainable params: 0
# _________________________________________________________________
# Train on 1 samples
# Epoch 1/100
# 1/1 [==============================] - 0s 170ms/sample - loss: 26218.8457
# Epoch 2/100
# 1/1 [==============================] - 0s 15ms/sample - loss: 29692.3770
# Epoch 3/100
# 1/1 [==============================] - 0s 10ms/sample - loss: 25977.1387
# Epoch 4/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 25834.5703
# Epoch 5/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 25909.6973
# Epoch 6/100
# 1/1 [==============================] - 0s 3ms/sample - loss: 24090.1016
# Epoch 7/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 21753.3438
# Epoch 8/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 19856.0352
# Epoch 9/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 18283.3047
# Epoch 10/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 16593.6328
# Epoch 11/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 14508.3535
# Epoch 12/100
# 1/1 [==============================] - 0s 3ms/sample - loss: 12069.6387
# Epoch 13/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 9635.4775
# Epoch 14/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 7698.7041
# Epoch 15/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 6391.7695
# Epoch 16/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 5354.5303
# Epoch 17/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 4326.0552
# Epoch 18/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 3371.0168
# Epoch 19/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 2488.2070
# Epoch 20/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 1667.1783
# Epoch 21/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 1097.6278
# Epoch 22/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 858.3899
# Epoch 23/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 757.8398
# Epoch 24/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 699.3184
# Epoch 25/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 719.2867
# Epoch 26/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 716.4211
# Epoch 27/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 646.1537
# Epoch 28/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 621.7758
# Epoch 29/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 609.0019
# Epoch 30/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 555.8710
# Epoch 31/100
# 1/1 [==============================] - 0s 5ms/sample - loss: 540.4049
# Epoch 32/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 507.6508
# Epoch 33/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 423.0136
# Epoch 34/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 367.8586
# Epoch 35/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 305.5722
# Epoch 36/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 250.0836
# Epoch 37/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 238.9029
# Epoch 38/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 205.4122
# Epoch 39/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 180.8750
# Epoch 40/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 156.9662
# Epoch 41/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 117.5531
# Epoch 42/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 109.2403
# Epoch 43/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 95.0296
# Epoch 44/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 93.6066
# Epoch 45/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 90.7540
# Epoch 46/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 74.6959
# Epoch 47/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 69.6760
# Epoch 48/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 55.0080
# Epoch 49/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 56.6189
# Epoch 50/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 53.0726
# Epoch 51/100
# 1/1 [==============================] - 0s 3ms/sample - loss: 52.3902
# Epoch 52/100
# 1/1 [==============================] - 0s 3ms/sample - loss: 47.9210
# Epoch 53/100
# 1/1 [==============================] - 0s 3ms/sample - loss: 39.8184
# Epoch 54/100
# 1/1 [==============================] - 0s 3ms/sample - loss: 36.9831
# Epoch 55/100
# 1/1 [==============================] - 0s 3ms/sample - loss: 31.6497
# Epoch 56/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 33.6536
# Epoch 57/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 29.3530
# Epoch 58/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 28.5425
# Epoch 59/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 21.9820
# Epoch 60/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 20.5841
# Epoch 61/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 17.3084
# Epoch 62/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 18.0238
# Epoch 63/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 15.6342
# Epoch 64/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 14.3999
# Epoch 65/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 11.1250
# Epoch 66/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 10.2489
# Epoch 67/100
# 1/1 [==============================] - 0s 3ms/sample - loss: 9.0296
# Epoch 68/100
# 1/1 [==============================] - 0s 3ms/sample - loss: 9.2815
# Epoch 69/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 7.9698
# Epoch 70/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 7.1768
# Epoch 71/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 5.5596
# Epoch 72/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 5.4459
# Epoch 73/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 4.8741
# Epoch 74/100
# 1/1 [==============================] - 0s 6ms/sample - loss: 5.1006
# Epoch 75/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 4.1311
# Epoch 76/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 3.8504
# Epoch 77/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 2.9869
# Epoch 78/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 3.1989
# Epoch 79/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 2.8011
# Epoch 80/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 2.8839
# Epoch 81/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 2.2408
# Epoch 82/100
# 1/1 [==============================] - 0s 4ms/sample - loss: 2.0861
# Epoch 83/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 1.7501
# Epoch 84/100
# 1/1 [==============================] - 0s 3ms/sample - loss: 1.8009
# Epoch 85/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 1.6698
# Epoch 86/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 1.4602
# Epoch 87/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 1.2602
# Epoch 88/100
# 1/1 [==============================] - 0s 3ms/sample - loss: 1.0247
# Epoch 89/100
# 1/1 [==============================] - 0s 3ms/sample - loss: 1.0781
# Epoch 90/100
# 1/1 [==============================] - 0s 3ms/sample - loss: 0.9369
# Epoch 91/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 0.9344
# Epoch 92/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 0.6958
# Epoch 93/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 0.6481
# Epoch 94/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 0.5811
# Epoch 95/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 0.5718
# Epoch 96/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 0.5400
# Epoch 97/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 0.4109
# Epoch 98/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 0.3910
# Epoch 99/100
# 1/1 [==============================] - 0s 4ms/sample - loss: 0.3239
# Epoch 100/100
# 1/1 [==============================] - 0s 2ms/sample - loss: 0.3544

# %%
#plot our loss 
plt.plot(np.log(history.history['loss']))
#plt.plot(np.log(history.history['val_loss']))
plt.title('model train vs validation loss')
plt.ylabel('log loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %% [markdown]
# #### Reconstruct Pavlos

# %%
### reconstruct pavlos
pavlos_flatten_reconstructed = autoencoder(pavlos_flatten.reshape(-1,input_dim)).numpy()
pavlos_reconstructed = pavlos_flatten_reconstructed.reshape(100,100)

# %%
fig, ax = plt.subplots(1,3, figsize=(9,4))

ax[0].imshow(pavlos_img_nice.reshape(100,100), cmap='gray')
ax[0].set_title('Original')
ax[0].axis('off')

ax[1].imshow(pavlos_reconstructed, cmap='gray')
ax[1].set_title('Recon')
ax[1].axis('off')

ax[2].imshow(pavlos_img_nice.reshape(100,100) - pavlos_reconstructed, cmap='gray');
ax[2].axis('off');

# %% [markdown]
# #### Reconstruct Eagle

# %%
### Lets do the eagle
### reconstruct eagle
notpavlos_flatten_reconstructed = autoencoder(notpavlos_flatten.reshape(-1,10000)).numpy()
notpavlos_reconstructed = notpavlos_flatten_reconstructed.reshape(100,100)

# %%
fig, ax = plt.subplots(1,3, figsize=(9,4))

ax[0].imshow(notpavlos_img_nice.reshape(100,100),cmap='gray')
ax[0].set_title('Eagle - original (A)')
ax[0].axis('off')

ax[1].imshow(notpavlos_reconstructed,cmap='gray')
ax[1].set_title('Eagle - Recon (B)')
ax[1].axis('off')

ax[2].imshow(notpavlos_img_nice.reshape(100,100) - notpavlos_reconstructed,cmap='gray')
ax[2].set_title('A - B')
ax[2].axis('off');

# %% [markdown]
# #### Reconstruct Not Pavlos i.e. Chris T.

# %%
### Lets do the not pavlos
### reconstruct not pavlos
notpavlos2_flatten_reconstructed = autoencoder(notpavlos2_flatten.reshape(-1,input_dim)).numpy()
notpavlos2_reconstructed = notpavlos2_flatten_reconstructed.reshape(100,100)

# %%
fig, ax = plt.subplots(1,3, figsize=(9,4))

ax[0].imshow(notpavlos2_img_nice.reshape(100,100),cmap='gray')
ax[0].set_title('Chris T - Not Pavlos \n original (A)')
ax[0].axis('off')

ax[1].imshow(notpavlos2_reconstructed,cmap='gray')
ax[1].set_title('Chris T - Not Pavlos \n Recon (B)')
ax[1].axis('off')

ax[2].imshow(notpavlos2_img_nice.reshape(100,100) - notpavlos_reconstructed,cmap='gray')
ax[2].set_title('A - B')
ax[2].axis('off');
